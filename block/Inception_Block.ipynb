# %% [markdown]
# ### https://deep-learning-study.tistory.com/525
# ### https://github.com/kentsommer/keras-inceptionV4/blob/master/inception_v4.py

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator, img_to_array, array_to_img, load_img
from tensorflow.keras.layers import Conv2D, MaxPool2D, Dense, Flatten, Dropout, BatchNormalization, GlobalAveragePooling2D
from tensorflow.keras.models import Sequential
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.applications import InceptionV3
from tensorflow.keras.optimizers import Adam, schedules
from tensorflow.keras import Input

import pandas as pd
import seaborn as sns
import numpy as np

# %%
img_width = 75
img_height = 75
img_channel = 3

# %%
from tensorflow.keras import backend as K
from tensorflow.keras import regularizers
from tensorflow.keras import initializers
from tensorflow.keras.layers import Activation, MaxPooling2D, Convolution2D, AveragePooling2D, Concatenate

def conv2d_bn(x, nb_filter, num_row, num_col,
              padding='same', strides=(1, 1), use_bias=False):
    if K.image_data_format() == 'channels_first':
        channel_axis = 1
    else:
        channel_axis = -1
    x = Convolution2D(nb_filter, (num_row, num_col),
                      strides=strides,
                      padding=padding,
                      use_bias=use_bias,
                      kernel_regularizer=regularizers.l2(0.00004),
                      kernel_initializer=initializers.VarianceScaling(scale=2.0, mode='fan_in', distribution='normal', seed=None))(x)
    x = BatchNormalization(axis=channel_axis, momentum=0.9997, scale=False)(x)
    x = Activation('relu')(x)
    return x


def block_inception_a(input):
    if K.image_data_format() == 'channels_first':
        channel_axis = 1
    else:
        channel_axis = -1

    branch_0 = conv2d_bn(input, 96, 1, 1)

    branch_1 = conv2d_bn(input, 64, 1, 1)
    branch_1 = conv2d_bn(branch_1, 96, 3, 3)

    branch_2 = conv2d_bn(input, 64, 1, 1)
    branch_2 = conv2d_bn(branch_2, 96, 3, 3)
    branch_2 = conv2d_bn(branch_2, 96, 3, 3)

    branch_3 = AveragePooling2D((3,3), strides=(1,1), padding='same')(input)
    branch_3 = conv2d_bn(branch_3, 96, 1, 1)

    x = Concatenate(axis=channel_axis)([branch_0, branch_1, branch_2, branch_3])
    return x

def block_reduction_a(input):
    if K.image_data_format() == 'channels_first':
        channel_axis = 1
    else:
        channel_axis = -1

    branch_0 = conv2d_bn(input, 384, 3, 3, strides=(2,2), padding='valid')

    branch_1 = conv2d_bn(input, 192, 1, 1)
    branch_1 = conv2d_bn(branch_1, 224, 3, 3)
    branch_1 = conv2d_bn(branch_1, 256, 3, 3, strides=(2,2), padding='valid')

    branch_2 = MaxPooling2D((3,3), strides=(2,2), padding='valid')(input)

    x = Concatenate(axis=channel_axis)([branch_0, branch_1, branch_2])
    return x

def block_inception_b(input):
    if K.image_data_format() == 'channels_first':
        channel_axis = 1
    else:
        channel_axis = -1

    branch_0 = conv2d_bn(input, 384, 1, 1)

    branch_1 = conv2d_bn(input, 192, 1, 1)
    branch_1 = conv2d_bn(branch_1, 224, 1, 7)
    branch_1 = conv2d_bn(branch_1, 256, 7, 1)

    branch_2 = conv2d_bn(input, 192, 1, 1)
    branch_2 = conv2d_bn(branch_2, 192, 7, 1)
    branch_2 = conv2d_bn(branch_2, 224, 1, 7)
    branch_2 = conv2d_bn(branch_2, 224, 7, 1)
    branch_2 = conv2d_bn(branch_2, 256, 1, 7)

    branch_3 = AveragePooling2D((3,3), strides=(1,1), padding='same')(input)
    branch_3 = conv2d_bn(branch_3, 128, 1, 1)

    x = Concatenate(axis=channel_axis)([branch_0, branch_1, branch_2, branch_3])
    return x


def block_reduction_b(input):
    if K.image_data_format() == 'channels_first':
        channel_axis = 1
    else:
        channel_axis = -1

    branch_0 = conv2d_bn(input, 192, 1, 1)
    branch_0 = conv2d_bn(branch_0, 192, 3, 3, strides=(2, 2), padding='valid')

    branch_1 = conv2d_bn(input, 256, 1, 1)
    branch_1 = conv2d_bn(branch_1, 256, 1, 7)
    branch_1 = conv2d_bn(branch_1, 320, 7, 1)
    branch_1 = conv2d_bn(branch_1, 320, 3, 3, strides=(2,2), padding='valid')

    branch_2 = MaxPooling2D((3, 3), strides=(2, 2), padding='valid')(input)

    x = Concatenate(axis=channel_axis)([branch_0, branch_1, branch_2])
    return x


def block_inception_c(input):
    if K.image_data_format() == 'channels_first':
        channel_axis = 1
    else:
        channel_axis = -1

    branch_0 = conv2d_bn(input, 256, 1, 1)

    branch_1 = conv2d_bn(input, 384, 1, 1)
    branch_10 = conv2d_bn(branch_1, 256, 1, 3)
    branch_11 = conv2d_bn(branch_1, 256, 3, 1)
    branch_1 = Concatenate(axis=channel_axis)([branch_10, branch_11])


    branch_2 = conv2d_bn(input, 384, 1, 1)
    branch_2 = conv2d_bn(branch_2, 448, 3, 1)
    branch_2 = conv2d_bn(branch_2, 512, 1, 3)
    branch_20 = conv2d_bn(branch_2, 256, 1, 3)
    branch_21 = conv2d_bn(branch_2, 256, 3, 1)
    branch_2 = Concatenate(axis=channel_axis)([branch_20, branch_21])

    branch_3 = AveragePooling2D((3, 3), strides=(1, 1), padding='same')(input)
    branch_3 = conv2d_bn(branch_3, 256, 1, 1)

    x = Concatenate(axis=channel_axis)([branch_0, branch_1, branch_2, branch_3])
    return x

# %%
inputs = Input(shape= (100,100, 3))
x = block_inception_a(inputs)
x = block_reduction_a(x)
x = block_inception_b(x)
x = block_reduction_b(x)
x = block_inception_c(x)
x = GlobalAveragePooling2D()(x)
x = Dense(512, activation='relu')(x)
x = Dropout(rate=0.6)(x)
predictions = Dense(3, activation='softmax')(x)

model = Model(inputs=inputs, outputs=predictions)

# %%
model.summary()
# Out:
# Model: "model_4"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_38 (InputLayer)           [(None, 100, 100, 3) 0
# __________________________________________________________________________________________________
# conv2d_482 (Conv2D)             (None, 100, 100, 64) 192         input_38[0][0]
# __________________________________________________________________________________________________
# batch_normalization_471 (BatchN (None, 100, 100, 64) 192         conv2d_482[0][0]
# __________________________________________________________________________________________________
# activation_470 (Activation)     (None, 100, 100, 64) 0           batch_normalization_471[0][0]
# __________________________________________________________________________________________________
# conv2d_480 (Conv2D)             (None, 100, 100, 64) 192         input_38[0][0]
# __________________________________________________________________________________________________
# conv2d_483 (Conv2D)             (None, 100, 100, 96) 55296       activation_470[0][0]
# __________________________________________________________________________________________________
# batch_normalization_469 (BatchN (None, 100, 100, 64) 192         conv2d_480[0][0]
# __________________________________________________________________________________________________
# batch_normalization_472 (BatchN (None, 100, 100, 96) 288         conv2d_483[0][0]
# __________________________________________________________________________________________________
# activation_468 (Activation)     (None, 100, 100, 64) 0           batch_normalization_469[0][0]
# __________________________________________________________________________________________________
# activation_471 (Activation)     (None, 100, 100, 96) 0           batch_normalization_472[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_47 (AveragePo (None, 100, 100, 3)  0           input_38[0][0]
# __________________________________________________________________________________________________
# conv2d_479 (Conv2D)             (None, 100, 100, 96) 288         input_38[0][0]
# __________________________________________________________________________________________________
# conv2d_481 (Conv2D)             (None, 100, 100, 96) 55296       activation_468[0][0]
# __________________________________________________________________________________________________
# conv2d_484 (Conv2D)             (None, 100, 100, 96) 82944       activation_471[0][0]
# __________________________________________________________________________________________________
# conv2d_485 (Conv2D)             (None, 100, 100, 96) 288         average_pooling2d_47[0][0]
# __________________________________________________________________________________________________
# batch_normalization_468 (BatchN (None, 100, 100, 96) 288         conv2d_479[0][0]
# __________________________________________________________________________________________________
# batch_normalization_470 (BatchN (None, 100, 100, 96) 288         conv2d_481[0][0]
# __________________________________________________________________________________________________
# batch_normalization_473 (BatchN (None, 100, 100, 96) 288         conv2d_484[0][0]
# __________________________________________________________________________________________________
# batch_normalization_474 (BatchN (None, 100, 100, 96) 288         conv2d_485[0][0]
# __________________________________________________________________________________________________
# activation_467 (Activation)     (None, 100, 100, 96) 0           batch_normalization_468[0][0]
# __________________________________________________________________________________________________
# activation_469 (Activation)     (None, 100, 100, 96) 0           batch_normalization_470[0][0]
# __________________________________________________________________________________________________
# activation_472 (Activation)     (None, 100, 100, 96) 0           batch_normalization_473[0][0]
# __________________________________________________________________________________________________
# activation_473 (Activation)     (None, 100, 100, 96) 0           batch_normalization_474[0][0]
# __________________________________________________________________________________________________
# concatenate_65 (Concatenate)    (None, 100, 100, 384 0           activation_467[0][0]
#                                                                  activation_469[0][0]
#                                                                  activation_472[0][0]
#                                                                  activation_473[0][0]
# __________________________________________________________________________________________________
# conv2d_487 (Conv2D)             (None, 100, 100, 192 73728       concatenate_65[0][0]
# __________________________________________________________________________________________________
# batch_normalization_476 (BatchN (None, 100, 100, 192 576         conv2d_487[0][0]
# __________________________________________________________________________________________________
# activation_475 (Activation)     (None, 100, 100, 192 0           batch_normalization_476[0][0]
# __________________________________________________________________________________________________
# conv2d_488 (Conv2D)             (None, 100, 100, 224 387072      activation_475[0][0]
# __________________________________________________________________________________________________
# batch_normalization_477 (BatchN (None, 100, 100, 224 672         conv2d_488[0][0]
# __________________________________________________________________________________________________
# activation_476 (Activation)     (None, 100, 100, 224 0           batch_normalization_477[0][0]
# __________________________________________________________________________________________________
# conv2d_486 (Conv2D)             (None, 49, 49, 384)  1327104     concatenate_65[0][0]
# __________________________________________________________________________________________________
# conv2d_489 (Conv2D)             (None, 49, 49, 256)  516096      activation_476[0][0]
# __________________________________________________________________________________________________
# batch_normalization_475 (BatchN (None, 49, 49, 384)  1152        conv2d_486[0][0]
# __________________________________________________________________________________________________
# batch_normalization_478 (BatchN (None, 49, 49, 256)  768         conv2d_489[0][0]
# __________________________________________________________________________________________________
# activation_474 (Activation)     (None, 49, 49, 384)  0           batch_normalization_475[0][0]
# __________________________________________________________________________________________________
# activation_477 (Activation)     (None, 49, 49, 256)  0           batch_normalization_478[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_18 (MaxPooling2D) (None, 49, 49, 384)  0           concatenate_65[0][0]
# __________________________________________________________________________________________________
# concatenate_66 (Concatenate)    (None, 49, 49, 1024) 0           activation_474[0][0]
#                                                                  activation_477[0][0]
#                                                                  max_pooling2d_18[0][0]
# __________________________________________________________________________________________________
# conv2d_494 (Conv2D)             (None, 49, 49, 192)  196608      concatenate_66[0][0]
# __________________________________________________________________________________________________
# batch_normalization_483 (BatchN (None, 49, 49, 192)  576         conv2d_494[0][0]
# __________________________________________________________________________________________________
# activation_482 (Activation)     (None, 49, 49, 192)  0           batch_normalization_483[0][0]
# __________________________________________________________________________________________________
# conv2d_495 (Conv2D)             (None, 49, 49, 192)  258048      activation_482[0][0]
# __________________________________________________________________________________________________
# batch_normalization_484 (BatchN (None, 49, 49, 192)  576         conv2d_495[0][0]
# __________________________________________________________________________________________________
# activation_483 (Activation)     (None, 49, 49, 192)  0           batch_normalization_484[0][0]
# __________________________________________________________________________________________________
# conv2d_491 (Conv2D)             (None, 49, 49, 192)  196608      concatenate_66[0][0]
# __________________________________________________________________________________________________
# conv2d_496 (Conv2D)             (None, 49, 49, 224)  301056      activation_483[0][0]
# __________________________________________________________________________________________________
# batch_normalization_480 (BatchN (None, 49, 49, 192)  576         conv2d_491[0][0]
# __________________________________________________________________________________________________
# batch_normalization_485 (BatchN (None, 49, 49, 224)  672         conv2d_496[0][0]
# __________________________________________________________________________________________________
# activation_479 (Activation)     (None, 49, 49, 192)  0           batch_normalization_480[0][0]
# __________________________________________________________________________________________________
# activation_484 (Activation)     (None, 49, 49, 224)  0           batch_normalization_485[0][0]
# __________________________________________________________________________________________________
# conv2d_492 (Conv2D)             (None, 49, 49, 224)  301056      activation_479[0][0]
# __________________________________________________________________________________________________
# conv2d_497 (Conv2D)             (None, 49, 49, 224)  351232      activation_484[0][0]
# __________________________________________________________________________________________________
# batch_normalization_481 (BatchN (None, 49, 49, 224)  672         conv2d_492[0][0]
# __________________________________________________________________________________________________
# batch_normalization_486 (BatchN (None, 49, 49, 224)  672         conv2d_497[0][0]
# __________________________________________________________________________________________________
# activation_480 (Activation)     (None, 49, 49, 224)  0           batch_normalization_481[0][0]
# __________________________________________________________________________________________________
# activation_485 (Activation)     (None, 49, 49, 224)  0           batch_normalization_486[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_48 (AveragePo (None, 49, 49, 1024) 0           concatenate_66[0][0]
# __________________________________________________________________________________________________
# conv2d_490 (Conv2D)             (None, 49, 49, 384)  393216      concatenate_66[0][0]
# __________________________________________________________________________________________________
# conv2d_493 (Conv2D)             (None, 49, 49, 256)  401408      activation_480[0][0]
# __________________________________________________________________________________________________
# conv2d_498 (Conv2D)             (None, 49, 49, 256)  401408      activation_485[0][0]
# __________________________________________________________________________________________________
# conv2d_499 (Conv2D)             (None, 49, 49, 128)  131072      average_pooling2d_48[0][0]
# __________________________________________________________________________________________________
# batch_normalization_479 (BatchN (None, 49, 49, 384)  1152        conv2d_490[0][0]
# __________________________________________________________________________________________________
# batch_normalization_482 (BatchN (None, 49, 49, 256)  768         conv2d_493[0][0]
# __________________________________________________________________________________________________
# batch_normalization_487 (BatchN (None, 49, 49, 256)  768         conv2d_498[0][0]
# __________________________________________________________________________________________________
# batch_normalization_488 (BatchN (None, 49, 49, 128)  384         conv2d_499[0][0]
# __________________________________________________________________________________________________
# activation_478 (Activation)     (None, 49, 49, 384)  0           batch_normalization_479[0][0]
# __________________________________________________________________________________________________
# activation_481 (Activation)     (None, 49, 49, 256)  0           batch_normalization_482[0][0]
# __________________________________________________________________________________________________
# activation_486 (Activation)     (None, 49, 49, 256)  0           batch_normalization_487[0][0]
# __________________________________________________________________________________________________
# activation_487 (Activation)     (None, 49, 49, 128)  0           batch_normalization_488[0][0]
# __________________________________________________________________________________________________
# concatenate_67 (Concatenate)    (None, 49, 49, 1024) 0           activation_478[0][0]
#                                                                  activation_481[0][0]
#                                                                  activation_486[0][0]
#                                                                  activation_487[0][0]
# __________________________________________________________________________________________________
# conv2d_502 (Conv2D)             (None, 49, 49, 256)  262144      concatenate_67[0][0]
# __________________________________________________________________________________________________
# batch_normalization_491 (BatchN (None, 49, 49, 256)  768         conv2d_502[0][0]
# __________________________________________________________________________________________________
# activation_490 (Activation)     (None, 49, 49, 256)  0           batch_normalization_491[0][0]
# __________________________________________________________________________________________________
# conv2d_503 (Conv2D)             (None, 49, 49, 256)  458752      activation_490[0][0]
# __________________________________________________________________________________________________
# batch_normalization_492 (BatchN (None, 49, 49, 256)  768         conv2d_503[0][0]
# __________________________________________________________________________________________________
# activation_491 (Activation)     (None, 49, 49, 256)  0           batch_normalization_492[0][0]
# __________________________________________________________________________________________________
# conv2d_500 (Conv2D)             (None, 49, 49, 192)  196608      concatenate_67[0][0]
# __________________________________________________________________________________________________
# conv2d_504 (Conv2D)             (None, 49, 49, 320)  573440      activation_491[0][0]
# __________________________________________________________________________________________________
# batch_normalization_489 (BatchN (None, 49, 49, 192)  576         conv2d_500[0][0]
# __________________________________________________________________________________________________
# batch_normalization_493 (BatchN (None, 49, 49, 320)  960         conv2d_504[0][0]
# __________________________________________________________________________________________________
# activation_488 (Activation)     (None, 49, 49, 192)  0           batch_normalization_489[0][0]
# __________________________________________________________________________________________________
# activation_492 (Activation)     (None, 49, 49, 320)  0           batch_normalization_493[0][0]
# __________________________________________________________________________________________________
# conv2d_501 (Conv2D)             (None, 24, 24, 192)  331776      activation_488[0][0]
# __________________________________________________________________________________________________
# conv2d_505 (Conv2D)             (None, 24, 24, 320)  921600      activation_492[0][0]
# __________________________________________________________________________________________________
# batch_normalization_490 (BatchN (None, 24, 24, 192)  576         conv2d_501[0][0]
# __________________________________________________________________________________________________
# batch_normalization_494 (BatchN (None, 24, 24, 320)  960         conv2d_505[0][0]
# __________________________________________________________________________________________________
# activation_489 (Activation)     (None, 24, 24, 192)  0           batch_normalization_490[0][0]
# __________________________________________________________________________________________________
# activation_493 (Activation)     (None, 24, 24, 320)  0           batch_normalization_494[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_19 (MaxPooling2D) (None, 24, 24, 1024) 0           concatenate_67[0][0]
# __________________________________________________________________________________________________
# concatenate_68 (Concatenate)    (None, 24, 24, 1536) 0           activation_489[0][0]
#                                                                  activation_493[0][0]
#                                                                  max_pooling2d_19[0][0]
# __________________________________________________________________________________________________
# conv2d_510 (Conv2D)             (None, 24, 24, 384)  589824      concatenate_68[0][0]
# __________________________________________________________________________________________________
# batch_normalization_499 (BatchN (None, 24, 24, 384)  1152        conv2d_510[0][0]
# __________________________________________________________________________________________________
# activation_498 (Activation)     (None, 24, 24, 384)  0           batch_normalization_499[0][0]
# __________________________________________________________________________________________________
# conv2d_511 (Conv2D)             (None, 24, 24, 448)  516096      activation_498[0][0]
# __________________________________________________________________________________________________
# batch_normalization_500 (BatchN (None, 24, 24, 448)  1344        conv2d_511[0][0]
# __________________________________________________________________________________________________
# activation_499 (Activation)     (None, 24, 24, 448)  0           batch_normalization_500[0][0]
# __________________________________________________________________________________________________
# conv2d_507 (Conv2D)             (None, 24, 24, 384)  589824      concatenate_68[0][0]
# __________________________________________________________________________________________________
# conv2d_512 (Conv2D)             (None, 24, 24, 512)  688128      activation_499[0][0]
# __________________________________________________________________________________________________
# batch_normalization_496 (BatchN (None, 24, 24, 384)  1152        conv2d_507[0][0]
# __________________________________________________________________________________________________
# batch_normalization_501 (BatchN (None, 24, 24, 512)  1536        conv2d_512[0][0]
# __________________________________________________________________________________________________
# activation_495 (Activation)     (None, 24, 24, 384)  0           batch_normalization_496[0][0]
# __________________________________________________________________________________________________
# activation_500 (Activation)     (None, 24, 24, 512)  0           batch_normalization_501[0][0]
# __________________________________________________________________________________________________
# conv2d_508 (Conv2D)             (None, 24, 24, 256)  294912      activation_495[0][0]
# __________________________________________________________________________________________________
# conv2d_509 (Conv2D)             (None, 24, 24, 256)  294912      activation_495[0][0]
# __________________________________________________________________________________________________
# conv2d_513 (Conv2D)             (None, 24, 24, 256)  393216      activation_500[0][0]
# __________________________________________________________________________________________________
# conv2d_514 (Conv2D)             (None, 24, 24, 256)  393216      activation_500[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_49 (AveragePo (None, 24, 24, 1536) 0           concatenate_68[0][0]
# __________________________________________________________________________________________________
# conv2d_506 (Conv2D)             (None, 24, 24, 256)  393216      concatenate_68[0][0]
# __________________________________________________________________________________________________
# batch_normalization_497 (BatchN (None, 24, 24, 256)  768         conv2d_508[0][0]
# __________________________________________________________________________________________________
# batch_normalization_498 (BatchN (None, 24, 24, 256)  768         conv2d_509[0][0]
# __________________________________________________________________________________________________
# batch_normalization_502 (BatchN (None, 24, 24, 256)  768         conv2d_513[0][0]
# __________________________________________________________________________________________________
# batch_normalization_503 (BatchN (None, 24, 24, 256)  768         conv2d_514[0][0]
# __________________________________________________________________________________________________
# conv2d_515 (Conv2D)             (None, 24, 24, 256)  393216      average_pooling2d_49[0][0]
# __________________________________________________________________________________________________
# batch_normalization_495 (BatchN (None, 24, 24, 256)  768         conv2d_506[0][0]
# __________________________________________________________________________________________________
# activation_496 (Activation)     (None, 24, 24, 256)  0           batch_normalization_497[0][0]
# __________________________________________________________________________________________________
# activation_497 (Activation)     (None, 24, 24, 256)  0           batch_normalization_498[0][0]
# __________________________________________________________________________________________________
# activation_501 (Activation)     (None, 24, 24, 256)  0           batch_normalization_502[0][0]
# __________________________________________________________________________________________________
# activation_502 (Activation)     (None, 24, 24, 256)  0           batch_normalization_503[0][0]
# __________________________________________________________________________________________________
# batch_normalization_504 (BatchN (None, 24, 24, 256)  768         conv2d_515[0][0]
# __________________________________________________________________________________________________
# activation_494 (Activation)     (None, 24, 24, 256)  0           batch_normalization_495[0][0]
# __________________________________________________________________________________________________
# concatenate_69 (Concatenate)    (None, 24, 24, 512)  0           activation_496[0][0]
#                                                                  activation_497[0][0]
# __________________________________________________________________________________________________
# concatenate_70 (Concatenate)    (None, 24, 24, 512)  0           activation_501[0][0]
#                                                                  activation_502[0][0]
# __________________________________________________________________________________________________
# activation_503 (Activation)     (None, 24, 24, 256)  0           batch_normalization_504[0][0]
# __________________________________________________________________________________________________
# concatenate_71 (Concatenate)    (None, 24, 24, 1536) 0           activation_494[0][0]
#                                                                  concatenate_69[0][0]
#                                                                  concatenate_70[0][0]
#                                                                  activation_503[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_4 (Glo (None, 1536)         0           concatenate_71[0][0]
# __________________________________________________________________________________________________
# dense_8 (Dense)                 (None, 512)          786944      global_average_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 512)          0           dense_8[0][0]
# __________________________________________________________________________________________________
# dense_9 (Dense)                 (None, 3)            1539        dropout_4[0][0]
# ==================================================================================================
# Total params: 13,535,779
# Trainable params: 13,518,307
# Non-trainable params: 17,472
# __________________________________________________________________________________________________

# %%
from tensorflow.keras.applications import VGG16
base_model = VGG16(weights='imagenet', include_top=False, input_shape = (img_height, img_width, img_channel))

# %%
x = base_model.output
x = block_inception_a(x)
# x = block_reduction_a(x)
# x = block_inception_b(x)
# x = block_reduction_b(x)
# x = block_inception_c(x)

x = GlobalAveragePooling2D()(x)
x = Dense(512, activation='relu')(x)
x = Dropout(rate=0.6)(x)
predictions = Dense(3, activation='softmax')(x)
model = Model(inputs=base_model.input, outputs=predictions)

# %%
model.summary()
# Out:
# Model: "model_6"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_40 (InputLayer)           [(None, 75, 75, 3)]  0
# __________________________________________________________________________________________________
# block1_conv1 (Conv2D)           (None, 75, 75, 64)   1792        input_40[0][0]
# __________________________________________________________________________________________________
# block1_conv2 (Conv2D)           (None, 75, 75, 64)   36928       block1_conv1[0][0]
# __________________________________________________________________________________________________
# block1_pool (MaxPooling2D)      (None, 37, 37, 64)   0           block1_conv2[0][0]
# __________________________________________________________________________________________________
# block2_conv1 (Conv2D)           (None, 37, 37, 128)  73856       block1_pool[0][0]
# __________________________________________________________________________________________________
# block2_conv2 (Conv2D)           (None, 37, 37, 128)  147584      block2_conv1[0][0]
# __________________________________________________________________________________________________
# block2_pool (MaxPooling2D)      (None, 18, 18, 128)  0           block2_conv2[0][0]
# __________________________________________________________________________________________________
# block3_conv1 (Conv2D)           (None, 18, 18, 256)  295168      block2_pool[0][0]
# __________________________________________________________________________________________________
# block3_conv2 (Conv2D)           (None, 18, 18, 256)  590080      block3_conv1[0][0]
# __________________________________________________________________________________________________
# block3_conv3 (Conv2D)           (None, 18, 18, 256)  590080      block3_conv2[0][0]
# __________________________________________________________________________________________________
# block3_pool (MaxPooling2D)      (None, 9, 9, 256)    0           block3_conv3[0][0]
# __________________________________________________________________________________________________
# block4_conv1 (Conv2D)           (None, 9, 9, 512)    1180160     block3_pool[0][0]
# __________________________________________________________________________________________________
# block4_conv2 (Conv2D)           (None, 9, 9, 512)    2359808     block4_conv1[0][0]
# __________________________________________________________________________________________________
# block4_conv3 (Conv2D)           (None, 9, 9, 512)    2359808     block4_conv2[0][0]
# __________________________________________________________________________________________________
# block4_pool (MaxPooling2D)      (None, 4, 4, 512)    0           block4_conv3[0][0]
# __________________________________________________________________________________________________
# block5_conv1 (Conv2D)           (None, 4, 4, 512)    2359808     block4_pool[0][0]
# __________________________________________________________________________________________________
# block5_conv2 (Conv2D)           (None, 4, 4, 512)    2359808     block5_conv1[0][0]
# __________________________________________________________________________________________________
# block5_conv3 (Conv2D)           (None, 4, 4, 512)    2359808     block5_conv2[0][0]
# __________________________________________________________________________________________________
# block5_pool (MaxPooling2D)      (None, 2, 2, 512)    0           block5_conv3[0][0]
# __________________________________________________________________________________________________
# conv2d_526 (Conv2D)             (None, 2, 2, 64)     32768       block5_pool[0][0]
# __________________________________________________________________________________________________
# batch_normalization_515 (BatchN (None, 2, 2, 64)     192         conv2d_526[0][0]
# __________________________________________________________________________________________________
# activation_514 (Activation)     (None, 2, 2, 64)     0           batch_normalization_515[0][0]
# __________________________________________________________________________________________________
# conv2d_524 (Conv2D)             (None, 2, 2, 64)     32768       block5_pool[0][0]
# __________________________________________________________________________________________________
# conv2d_527 (Conv2D)             (None, 2, 2, 96)     55296       activation_514[0][0]
# __________________________________________________________________________________________________
# batch_normalization_513 (BatchN (None, 2, 2, 64)     192         conv2d_524[0][0]
# __________________________________________________________________________________________________
# batch_normalization_516 (BatchN (None, 2, 2, 96)     288         conv2d_527[0][0]
# __________________________________________________________________________________________________
# activation_512 (Activation)     (None, 2, 2, 64)     0           batch_normalization_513[0][0]
# __________________________________________________________________________________________________
# activation_515 (Activation)     (None, 2, 2, 96)     0           batch_normalization_516[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_51 (AveragePo (None, 2, 2, 512)    0           block5_pool[0][0]
# __________________________________________________________________________________________________
# conv2d_523 (Conv2D)             (None, 2, 2, 96)     49152       block5_pool[0][0]
# __________________________________________________________________________________________________
# conv2d_525 (Conv2D)             (None, 2, 2, 96)     55296       activation_512[0][0]
# __________________________________________________________________________________________________
# conv2d_528 (Conv2D)             (None, 2, 2, 96)     82944       activation_515[0][0]
# __________________________________________________________________________________________________
# conv2d_529 (Conv2D)             (None, 2, 2, 96)     49152       average_pooling2d_51[0][0]
# __________________________________________________________________________________________________
# batch_normalization_512 (BatchN (None, 2, 2, 96)     288         conv2d_523[0][0]
# __________________________________________________________________________________________________
# batch_normalization_514 (BatchN (None, 2, 2, 96)     288         conv2d_525[0][0]
# __________________________________________________________________________________________________
# batch_normalization_517 (BatchN (None, 2, 2, 96)     288         conv2d_528[0][0]
# __________________________________________________________________________________________________
# batch_normalization_518 (BatchN (None, 2, 2, 96)     288         conv2d_529[0][0]
# __________________________________________________________________________________________________
# activation_511 (Activation)     (None, 2, 2, 96)     0           batch_normalization_512[0][0]
# __________________________________________________________________________________________________
# activation_513 (Activation)     (None, 2, 2, 96)     0           batch_normalization_514[0][0]
# __________________________________________________________________________________________________
# activation_516 (Activation)     (None, 2, 2, 96)     0           batch_normalization_517[0][0]
# __________________________________________________________________________________________________
# activation_517 (Activation)     (None, 2, 2, 96)     0           batch_normalization_518[0][0]
# __________________________________________________________________________________________________
# concatenate_73 (Concatenate)    (None, 2, 2, 384)    0           activation_511[0][0]
#                                                                  activation_513[0][0]
#                                                                  activation_516[0][0]
#                                                                  activation_517[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_6 (Glo (None, 384)          0           concatenate_73[0][0]
# __________________________________________________________________________________________________
# dense_12 (Dense)                (None, 512)          197120      global_average_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 512)          0           dense_12[0][0]
# __________________________________________________________________________________________________
# dense_13 (Dense)                (None, 3)            1539        dropout_6[0][0]
# ==================================================================================================
# Total params: 15,272,547
# Trainable params: 15,271,331
# Non-trainable params: 1,216
# __________________________________________________________________________________________________
