# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator, img_to_array, array_to_img, load_img
from tensorflow.keras.layers import Conv2D, MaxPool2D, Dense, Flatten, Dropout, BatchNormalization
from tensorflow.keras.layers import GlobalAveragePooling2D, ZeroPadding2D, Activation, Add, AveragePooling2D
from tensorflow.keras.models import Sequential
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.applications import InceptionV3
from tensorflow.keras.optimizers import Adam, schedules
from tensorflow.keras import Input
from tensorflow.keras.regularizers import L2

import pandas as pd
import seaborn as sns
import numpy as np

# %%
def res_identity(x, filters): 
  #renet block where dimension doesnot change.
  #The skip connection is just simple identity conncection
  #we will have 3 blocks and then input will be added

    x_skip = x # this will be used for addition with the residual block 
    f1, f2 = filters

  #first block 
    x = Conv2D(f1, kernel_size=(1, 1), strides=(1, 1), padding='valid', kernel_regularizer=L2(0.001))(x)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)

  #second block # bottleneck (but size kept same with padding)
    x = Conv2D(f1, kernel_size=(3, 3), strides=(1, 1), padding='same', kernel_regularizer=L2(0.001))(x)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)

  # third block activation used after adding the input
    x = Conv2D(f2, kernel_size=(1, 1), strides=(1, 1), padding='valid', kernel_regularizer=L2(0.001))(x)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)

  # add the input 
    x = Add()([x, x_skip])
    x = Activation("relu")(x)
    return x

# %%
def res_conv(x, s, filters):
 
    x_skip = x
    f1, f2 = filters

  # first block
    x = Conv2D(f1, kernel_size=(1, 1), strides=(s, s), padding='valid', kernel_regularizer=L2(0.001))(x)
  # when s = 2 then it is like downsizing the feature map
    x = BatchNormalization()(x)
    x = Activation("relu")(x)

  # second block
    x = Conv2D(f1, kernel_size=(3, 3), strides=(1, 1), padding='same', kernel_regularizer=L2(0.001))(x)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)

  #third block
    x = Conv2D(f2, kernel_size=(1, 1), strides=(1, 1), padding='valid', kernel_regularizer=L2(0.001))(x)
    x = BatchNormalization()(x)

  # shortcut 
    x_skip = Conv2D(f2, kernel_size=(1, 1), strides=(s, s), padding='valid', kernel_regularizer=L2(0.001))(x_skip)
    x_skip = BatchNormalization()(x_skip)

  # add 
    x = Add()([x, x_skip])
    x = Activation("relu")(x)
    return x

# %%
def resnet50():
    input_im = Input(shape=(100,100,3)) # cifar 10 images size
    x = ZeroPadding2D(padding=(3, 3))(input_im)

  # 1st stage
  # here we perform maxpooling, see the figure above

    x = Conv2D(64, kernel_size=(7, 7), strides=(2, 2))(x)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)
    x = MaxPool2D((3, 3), strides=(2, 2))(x)

  #2nd stage 
  # frm here on only conv block and identity block, no pooling

    x = res_conv(x, s=1, filters=(64, 256))
    x = res_identity(x, filters=(64, 256))
    x = res_identity(x, filters=(64, 256))

  # 3rd stage

    x = res_conv(x, s=2, filters=(128, 512))
    x = res_identity(x, filters=(128, 512))
    x = res_identity(x, filters=(128, 512))
    x = res_identity(x, filters=(128, 512))

  # 4th stage

    x = res_conv(x, s=2, filters=(256, 1024))
    x = res_identity(x, filters=(256, 1024))
    x = res_identity(x, filters=(256, 1024))
    x = res_identity(x, filters=(256, 1024))
    x = res_identity(x, filters=(256, 1024))
    x = res_identity(x, filters=(256, 1024))

  # 5th stage

    x = res_conv(x, s=2, filters=(512, 2048))
    x = res_identity(x, filters=(512, 2048))
    x = res_identity(x, filters=(512, 2048))

  # ends with average pooling and dense connection

    x = AveragePooling2D((2, 2), padding='same')(x)

    x = Flatten()(x)
    x = Dense(3, activation='softmax', kernel_initializer='he_normal')(x) #multi-class

  # define the model 

    model = Model(inputs=input_im, outputs=x, name='Resnet50')

    return model

# %%
model = resnet50()

# %%
model.summary()
# Out:
# Model: "Resnet50"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_13 (InputLayer)           [(None, 100, 100, 3) 0
# __________________________________________________________________________________________________
# zero_padding2d_11 (ZeroPadding2 (None, 106, 106, 3)  0           input_13[0][0]
# __________________________________________________________________________________________________
# conv2d_175 (Conv2D)             (None, 50, 50, 64)   9472        zero_padding2d_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_175 (BatchN (None, 50, 50, 64)   256         conv2d_175[0][0]
# __________________________________________________________________________________________________
# activation_191 (Activation)     (None, 50, 50, 64)   0           batch_normalization_175[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_6 (MaxPooling2D)  (None, 24, 24, 64)   0           activation_191[0][0]
# __________________________________________________________________________________________________
# conv2d_176 (Conv2D)             (None, 24, 24, 64)   4160        max_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_176 (BatchN (None, 24, 24, 64)   256         conv2d_176[0][0]
# __________________________________________________________________________________________________
# activation_192 (Activation)     (None, 24, 24, 64)   0           batch_normalization_176[0][0]
# __________________________________________________________________________________________________
# conv2d_177 (Conv2D)             (None, 24, 24, 64)   36928       activation_192[0][0]
# __________________________________________________________________________________________________
# batch_normalization_177 (BatchN (None, 24, 24, 64)   256         conv2d_177[0][0]
# __________________________________________________________________________________________________
# activation_193 (Activation)     (None, 24, 24, 64)   0           batch_normalization_177[0][0]
# __________________________________________________________________________________________________
# conv2d_178 (Conv2D)             (None, 24, 24, 256)  16640       activation_193[0][0]
# __________________________________________________________________________________________________
# conv2d_179 (Conv2D)             (None, 24, 24, 256)  16640       max_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_178 (BatchN (None, 24, 24, 256)  1024        conv2d_178[0][0]
# __________________________________________________________________________________________________
# batch_normalization_179 (BatchN (None, 24, 24, 256)  1024        conv2d_179[0][0]
# __________________________________________________________________________________________________
# add_49 (Add)                    (None, 24, 24, 256)  0           batch_normalization_178[0][0]
#                                                                  batch_normalization_179[0][0]
# __________________________________________________________________________________________________
# activation_194 (Activation)     (None, 24, 24, 256)  0           add_49[0][0]
# __________________________________________________________________________________________________
# conv2d_180 (Conv2D)             (None, 24, 24, 64)   16448       activation_194[0][0]
# __________________________________________________________________________________________________
# batch_normalization_180 (BatchN (None, 24, 24, 64)   256         conv2d_180[0][0]
# __________________________________________________________________________________________________
# activation_195 (Activation)     (None, 24, 24, 64)   0           batch_normalization_180[0][0]
# __________________________________________________________________________________________________
# conv2d_181 (Conv2D)             (None, 24, 24, 64)   36928       activation_195[0][0]
# __________________________________________________________________________________________________
# batch_normalization_181 (BatchN (None, 24, 24, 64)   256         conv2d_181[0][0]
# __________________________________________________________________________________________________
# activation_196 (Activation)     (None, 24, 24, 64)   0           batch_normalization_181[0][0]
# __________________________________________________________________________________________________
# conv2d_182 (Conv2D)             (None, 24, 24, 256)  16640       activation_196[0][0]
# __________________________________________________________________________________________________
# batch_normalization_182 (BatchN (None, 24, 24, 256)  1024        conv2d_182[0][0]
# __________________________________________________________________________________________________
# activation_197 (Activation)     (None, 24, 24, 256)  0           batch_normalization_182[0][0]
# __________________________________________________________________________________________________
# add_50 (Add)                    (None, 24, 24, 256)  0           activation_197[0][0]
#                                                                  activation_194[0][0]
# __________________________________________________________________________________________________
# activation_198 (Activation)     (None, 24, 24, 256)  0           add_50[0][0]
# __________________________________________________________________________________________________
# conv2d_183 (Conv2D)             (None, 24, 24, 64)   16448       activation_198[0][0]
# __________________________________________________________________________________________________
# batch_normalization_183 (BatchN (None, 24, 24, 64)   256         conv2d_183[0][0]
# __________________________________________________________________________________________________
# activation_199 (Activation)     (None, 24, 24, 64)   0           batch_normalization_183[0][0]
# __________________________________________________________________________________________________
# conv2d_184 (Conv2D)             (None, 24, 24, 64)   36928       activation_199[0][0]
# __________________________________________________________________________________________________
# batch_normalization_184 (BatchN (None, 24, 24, 64)   256         conv2d_184[0][0]
# __________________________________________________________________________________________________
# activation_200 (Activation)     (None, 24, 24, 64)   0           batch_normalization_184[0][0]
# __________________________________________________________________________________________________
# conv2d_185 (Conv2D)             (None, 24, 24, 256)  16640       activation_200[0][0]
# __________________________________________________________________________________________________
# batch_normalization_185 (BatchN (None, 24, 24, 256)  1024        conv2d_185[0][0]
# __________________________________________________________________________________________________
# activation_201 (Activation)     (None, 24, 24, 256)  0           batch_normalization_185[0][0]
# __________________________________________________________________________________________________
# add_51 (Add)                    (None, 24, 24, 256)  0           activation_201[0][0]
#                                                                  activation_198[0][0]
# __________________________________________________________________________________________________
# activation_202 (Activation)     (None, 24, 24, 256)  0           add_51[0][0]
# __________________________________________________________________________________________________
# conv2d_186 (Conv2D)             (None, 12, 12, 128)  32896       activation_202[0][0]
# __________________________________________________________________________________________________
# batch_normalization_186 (BatchN (None, 12, 12, 128)  512         conv2d_186[0][0]
# __________________________________________________________________________________________________
# activation_203 (Activation)     (None, 12, 12, 128)  0           batch_normalization_186[0][0]
# __________________________________________________________________________________________________
# conv2d_187 (Conv2D)             (None, 12, 12, 128)  147584      activation_203[0][0]
# __________________________________________________________________________________________________
# batch_normalization_187 (BatchN (None, 12, 12, 128)  512         conv2d_187[0][0]
# __________________________________________________________________________________________________
# activation_204 (Activation)     (None, 12, 12, 128)  0           batch_normalization_187[0][0]
# __________________________________________________________________________________________________
# conv2d_188 (Conv2D)             (None, 12, 12, 512)  66048       activation_204[0][0]
# __________________________________________________________________________________________________
# conv2d_189 (Conv2D)             (None, 12, 12, 512)  131584      activation_202[0][0]
# __________________________________________________________________________________________________
# batch_normalization_188 (BatchN (None, 12, 12, 512)  2048        conv2d_188[0][0]
# __________________________________________________________________________________________________
# batch_normalization_189 (BatchN (None, 12, 12, 512)  2048        conv2d_189[0][0]
# __________________________________________________________________________________________________
# add_52 (Add)                    (None, 12, 12, 512)  0           batch_normalization_188[0][0]
#                                                                  batch_normalization_189[0][0]
# __________________________________________________________________________________________________
# activation_205 (Activation)     (None, 12, 12, 512)  0           add_52[0][0]
# __________________________________________________________________________________________________
# conv2d_190 (Conv2D)             (None, 12, 12, 128)  65664       activation_205[0][0]
# __________________________________________________________________________________________________
# batch_normalization_190 (BatchN (None, 12, 12, 128)  512         conv2d_190[0][0]
# __________________________________________________________________________________________________
# activation_206 (Activation)     (None, 12, 12, 128)  0           batch_normalization_190[0][0]
# __________________________________________________________________________________________________
# conv2d_191 (Conv2D)             (None, 12, 12, 128)  147584      activation_206[0][0]
# __________________________________________________________________________________________________
# batch_normalization_191 (BatchN (None, 12, 12, 128)  512         conv2d_191[0][0]
# __________________________________________________________________________________________________
# activation_207 (Activation)     (None, 12, 12, 128)  0           batch_normalization_191[0][0]
# __________________________________________________________________________________________________
# conv2d_192 (Conv2D)             (None, 12, 12, 512)  66048       activation_207[0][0]
# __________________________________________________________________________________________________
# batch_normalization_192 (BatchN (None, 12, 12, 512)  2048        conv2d_192[0][0]
# __________________________________________________________________________________________________
# activation_208 (Activation)     (None, 12, 12, 512)  0           batch_normalization_192[0][0]
# __________________________________________________________________________________________________
# add_53 (Add)                    (None, 12, 12, 512)  0           activation_208[0][0]
#                                                                  activation_205[0][0]
# __________________________________________________________________________________________________
# activation_209 (Activation)     (None, 12, 12, 512)  0           add_53[0][0]
# __________________________________________________________________________________________________
# conv2d_193 (Conv2D)             (None, 12, 12, 128)  65664       activation_209[0][0]
# __________________________________________________________________________________________________
# batch_normalization_193 (BatchN (None, 12, 12, 128)  512         conv2d_193[0][0]
# __________________________________________________________________________________________________
# activation_210 (Activation)     (None, 12, 12, 128)  0           batch_normalization_193[0][0]
# __________________________________________________________________________________________________
# conv2d_194 (Conv2D)             (None, 12, 12, 128)  147584      activation_210[0][0]
# __________________________________________________________________________________________________
# batch_normalization_194 (BatchN (None, 12, 12, 128)  512         conv2d_194[0][0]
# __________________________________________________________________________________________________
# activation_211 (Activation)     (None, 12, 12, 128)  0           batch_normalization_194[0][0]
# __________________________________________________________________________________________________
# conv2d_195 (Conv2D)             (None, 12, 12, 512)  66048       activation_211[0][0]
# __________________________________________________________________________________________________
# batch_normalization_195 (BatchN (None, 12, 12, 512)  2048        conv2d_195[0][0]
# __________________________________________________________________________________________________
# activation_212 (Activation)     (None, 12, 12, 512)  0           batch_normalization_195[0][0]
# __________________________________________________________________________________________________
# add_54 (Add)                    (None, 12, 12, 512)  0           activation_212[0][0]
#                                                                  activation_209[0][0]
# __________________________________________________________________________________________________
# activation_213 (Activation)     (None, 12, 12, 512)  0           add_54[0][0]
# __________________________________________________________________________________________________
# conv2d_196 (Conv2D)             (None, 12, 12, 128)  65664       activation_213[0][0]
# __________________________________________________________________________________________________
# batch_normalization_196 (BatchN (None, 12, 12, 128)  512         conv2d_196[0][0]
# __________________________________________________________________________________________________
# activation_214 (Activation)     (None, 12, 12, 128)  0           batch_normalization_196[0][0]
# __________________________________________________________________________________________________
# conv2d_197 (Conv2D)             (None, 12, 12, 128)  147584      activation_214[0][0]
# __________________________________________________________________________________________________
# batch_normalization_197 (BatchN (None, 12, 12, 128)  512         conv2d_197[0][0]
# __________________________________________________________________________________________________
# activation_215 (Activation)     (None, 12, 12, 128)  0           batch_normalization_197[0][0]
# __________________________________________________________________________________________________
# conv2d_198 (Conv2D)             (None, 12, 12, 512)  66048       activation_215[0][0]
# __________________________________________________________________________________________________
# batch_normalization_198 (BatchN (None, 12, 12, 512)  2048        conv2d_198[0][0]
# __________________________________________________________________________________________________
# activation_216 (Activation)     (None, 12, 12, 512)  0           batch_normalization_198[0][0]
# __________________________________________________________________________________________________
# add_55 (Add)                    (None, 12, 12, 512)  0           activation_216[0][0]
#                                                                  activation_213[0][0]
# __________________________________________________________________________________________________
# activation_217 (Activation)     (None, 12, 12, 512)  0           add_55[0][0]
# __________________________________________________________________________________________________
# conv2d_199 (Conv2D)             (None, 6, 6, 256)    131328      activation_217[0][0]
# __________________________________________________________________________________________________
# batch_normalization_199 (BatchN (None, 6, 6, 256)    1024        conv2d_199[0][0]
# __________________________________________________________________________________________________
# activation_218 (Activation)     (None, 6, 6, 256)    0           batch_normalization_199[0][0]
# __________________________________________________________________________________________________
# conv2d_200 (Conv2D)             (None, 6, 6, 256)    590080      activation_218[0][0]
# __________________________________________________________________________________________________
# batch_normalization_200 (BatchN (None, 6, 6, 256)    1024        conv2d_200[0][0]
# __________________________________________________________________________________________________
# activation_219 (Activation)     (None, 6, 6, 256)    0           batch_normalization_200[0][0]
# __________________________________________________________________________________________________
# conv2d_201 (Conv2D)             (None, 6, 6, 1024)   263168      activation_219[0][0]
# __________________________________________________________________________________________________
# conv2d_202 (Conv2D)             (None, 6, 6, 1024)   525312      activation_217[0][0]
# __________________________________________________________________________________________________
# batch_normalization_201 (BatchN (None, 6, 6, 1024)   4096        conv2d_201[0][0]
# __________________________________________________________________________________________________
# batch_normalization_202 (BatchN (None, 6, 6, 1024)   4096        conv2d_202[0][0]
# __________________________________________________________________________________________________
# add_56 (Add)                    (None, 6, 6, 1024)   0           batch_normalization_201[0][0]
#                                                                  batch_normalization_202[0][0]
# __________________________________________________________________________________________________
# activation_220 (Activation)     (None, 6, 6, 1024)   0           add_56[0][0]
# __________________________________________________________________________________________________
# conv2d_203 (Conv2D)             (None, 6, 6, 256)    262400      activation_220[0][0]
# __________________________________________________________________________________________________
# batch_normalization_203 (BatchN (None, 6, 6, 256)    1024        conv2d_203[0][0]
# __________________________________________________________________________________________________
# activation_221 (Activation)     (None, 6, 6, 256)    0           batch_normalization_203[0][0]
# __________________________________________________________________________________________________
# conv2d_204 (Conv2D)             (None, 6, 6, 256)    590080      activation_221[0][0]
# __________________________________________________________________________________________________
# batch_normalization_204 (BatchN (None, 6, 6, 256)    1024        conv2d_204[0][0]
# __________________________________________________________________________________________________
# activation_222 (Activation)     (None, 6, 6, 256)    0           batch_normalization_204[0][0]
# __________________________________________________________________________________________________
# conv2d_205 (Conv2D)             (None, 6, 6, 1024)   263168      activation_222[0][0]
# __________________________________________________________________________________________________
# batch_normalization_205 (BatchN (None, 6, 6, 1024)   4096        conv2d_205[0][0]
# __________________________________________________________________________________________________
# activation_223 (Activation)     (None, 6, 6, 1024)   0           batch_normalization_205[0][0]
# __________________________________________________________________________________________________
# add_57 (Add)                    (None, 6, 6, 1024)   0           activation_223[0][0]
#                                                                  activation_220[0][0]
# __________________________________________________________________________________________________
# activation_224 (Activation)     (None, 6, 6, 1024)   0           add_57[0][0]
# __________________________________________________________________________________________________
# conv2d_206 (Conv2D)             (None, 6, 6, 256)    262400      activation_224[0][0]
# __________________________________________________________________________________________________
# batch_normalization_206 (BatchN (None, 6, 6, 256)    1024        conv2d_206[0][0]
# __________________________________________________________________________________________________
# activation_225 (Activation)     (None, 6, 6, 256)    0           batch_normalization_206[0][0]
# __________________________________________________________________________________________________
# conv2d_207 (Conv2D)             (None, 6, 6, 256)    590080      activation_225[0][0]
# __________________________________________________________________________________________________
# batch_normalization_207 (BatchN (None, 6, 6, 256)    1024        conv2d_207[0][0]
# __________________________________________________________________________________________________
# activation_226 (Activation)     (None, 6, 6, 256)    0           batch_normalization_207[0][0]
# __________________________________________________________________________________________________
# conv2d_208 (Conv2D)             (None, 6, 6, 1024)   263168      activation_226[0][0]
# __________________________________________________________________________________________________
# batch_normalization_208 (BatchN (None, 6, 6, 1024)   4096        conv2d_208[0][0]
# __________________________________________________________________________________________________
# activation_227 (Activation)     (None, 6, 6, 1024)   0           batch_normalization_208[0][0]
# __________________________________________________________________________________________________
# add_58 (Add)                    (None, 6, 6, 1024)   0           activation_227[0][0]
#                                                                  activation_224[0][0]
# __________________________________________________________________________________________________
# activation_228 (Activation)     (None, 6, 6, 1024)   0           add_58[0][0]
# __________________________________________________________________________________________________
# conv2d_209 (Conv2D)             (None, 6, 6, 256)    262400      activation_228[0][0]
# __________________________________________________________________________________________________
# batch_normalization_209 (BatchN (None, 6, 6, 256)    1024        conv2d_209[0][0]
# __________________________________________________________________________________________________
# activation_229 (Activation)     (None, 6, 6, 256)    0           batch_normalization_209[0][0]
# __________________________________________________________________________________________________
# conv2d_210 (Conv2D)             (None, 6, 6, 256)    590080      activation_229[0][0]
# __________________________________________________________________________________________________
# batch_normalization_210 (BatchN (None, 6, 6, 256)    1024        conv2d_210[0][0]
# __________________________________________________________________________________________________
# activation_230 (Activation)     (None, 6, 6, 256)    0           batch_normalization_210[0][0]
# __________________________________________________________________________________________________
# conv2d_211 (Conv2D)             (None, 6, 6, 1024)   263168      activation_230[0][0]
# __________________________________________________________________________________________________
# batch_normalization_211 (BatchN (None, 6, 6, 1024)   4096        conv2d_211[0][0]
# __________________________________________________________________________________________________
# activation_231 (Activation)     (None, 6, 6, 1024)   0           batch_normalization_211[0][0]
# __________________________________________________________________________________________________
# add_59 (Add)                    (None, 6, 6, 1024)   0           activation_231[0][0]
#                                                                  activation_228[0][0]
# __________________________________________________________________________________________________
# activation_232 (Activation)     (None, 6, 6, 1024)   0           add_59[0][0]
# __________________________________________________________________________________________________
# conv2d_212 (Conv2D)             (None, 6, 6, 256)    262400      activation_232[0][0]
# __________________________________________________________________________________________________
# batch_normalization_212 (BatchN (None, 6, 6, 256)    1024        conv2d_212[0][0]
# __________________________________________________________________________________________________
# activation_233 (Activation)     (None, 6, 6, 256)    0           batch_normalization_212[0][0]
# __________________________________________________________________________________________________
# conv2d_213 (Conv2D)             (None, 6, 6, 256)    590080      activation_233[0][0]
# __________________________________________________________________________________________________
# batch_normalization_213 (BatchN (None, 6, 6, 256)    1024        conv2d_213[0][0]
# __________________________________________________________________________________________________
# activation_234 (Activation)     (None, 6, 6, 256)    0           batch_normalization_213[0][0]
# __________________________________________________________________________________________________
# conv2d_214 (Conv2D)             (None, 6, 6, 1024)   263168      activation_234[0][0]
# __________________________________________________________________________________________________
# batch_normalization_214 (BatchN (None, 6, 6, 1024)   4096        conv2d_214[0][0]
# __________________________________________________________________________________________________
# activation_235 (Activation)     (None, 6, 6, 1024)   0           batch_normalization_214[0][0]
# __________________________________________________________________________________________________
# add_60 (Add)                    (None, 6, 6, 1024)   0           activation_235[0][0]
#                                                                  activation_232[0][0]
# __________________________________________________________________________________________________
# activation_236 (Activation)     (None, 6, 6, 1024)   0           add_60[0][0]
# __________________________________________________________________________________________________
# conv2d_215 (Conv2D)             (None, 6, 6, 256)    262400      activation_236[0][0]
# __________________________________________________________________________________________________
# batch_normalization_215 (BatchN (None, 6, 6, 256)    1024        conv2d_215[0][0]
# __________________________________________________________________________________________________
# activation_237 (Activation)     (None, 6, 6, 256)    0           batch_normalization_215[0][0]
# __________________________________________________________________________________________________
# conv2d_216 (Conv2D)             (None, 6, 6, 256)    590080      activation_237[0][0]
# __________________________________________________________________________________________________
# batch_normalization_216 (BatchN (None, 6, 6, 256)    1024        conv2d_216[0][0]
# __________________________________________________________________________________________________
# activation_238 (Activation)     (None, 6, 6, 256)    0           batch_normalization_216[0][0]
# __________________________________________________________________________________________________
# conv2d_217 (Conv2D)             (None, 6, 6, 1024)   263168      activation_238[0][0]
# __________________________________________________________________________________________________
# batch_normalization_217 (BatchN (None, 6, 6, 1024)   4096        conv2d_217[0][0]
# __________________________________________________________________________________________________
# activation_239 (Activation)     (None, 6, 6, 1024)   0           batch_normalization_217[0][0]
# __________________________________________________________________________________________________
# add_61 (Add)                    (None, 6, 6, 1024)   0           activation_239[0][0]
#                                                                  activation_236[0][0]
# __________________________________________________________________________________________________
# activation_240 (Activation)     (None, 6, 6, 1024)   0           add_61[0][0]
# __________________________________________________________________________________________________
# conv2d_218 (Conv2D)             (None, 3, 3, 512)    524800      activation_240[0][0]
# __________________________________________________________________________________________________
# batch_normalization_218 (BatchN (None, 3, 3, 512)    2048        conv2d_218[0][0]
# __________________________________________________________________________________________________
# activation_241 (Activation)     (None, 3, 3, 512)    0           batch_normalization_218[0][0]
# __________________________________________________________________________________________________
# conv2d_219 (Conv2D)             (None, 3, 3, 512)    2359808     activation_241[0][0]
# __________________________________________________________________________________________________
# batch_normalization_219 (BatchN (None, 3, 3, 512)    2048        conv2d_219[0][0]
# __________________________________________________________________________________________________
# activation_242 (Activation)     (None, 3, 3, 512)    0           batch_normalization_219[0][0]
# __________________________________________________________________________________________________
# conv2d_220 (Conv2D)             (None, 3, 3, 2048)   1050624     activation_242[0][0]
# __________________________________________________________________________________________________
# conv2d_221 (Conv2D)             (None, 3, 3, 2048)   2099200     activation_240[0][0]
# __________________________________________________________________________________________________
# batch_normalization_220 (BatchN (None, 3, 3, 2048)   8192        conv2d_220[0][0]
# __________________________________________________________________________________________________
# batch_normalization_221 (BatchN (None, 3, 3, 2048)   8192        conv2d_221[0][0]
# __________________________________________________________________________________________________
# add_62 (Add)                    (None, 3, 3, 2048)   0           batch_normalization_220[0][0]
#                                                                  batch_normalization_221[0][0]
# __________________________________________________________________________________________________
# activation_243 (Activation)     (None, 3, 3, 2048)   0           add_62[0][0]
# __________________________________________________________________________________________________
# conv2d_222 (Conv2D)             (None, 3, 3, 512)    1049088     activation_243[0][0]
# __________________________________________________________________________________________________
# batch_normalization_222 (BatchN (None, 3, 3, 512)    2048        conv2d_222[0][0]
# __________________________________________________________________________________________________
# activation_244 (Activation)     (None, 3, 3, 512)    0           batch_normalization_222[0][0]
# __________________________________________________________________________________________________
# conv2d_223 (Conv2D)             (None, 3, 3, 512)    2359808     activation_244[0][0]
# __________________________________________________________________________________________________
# batch_normalization_223 (BatchN (None, 3, 3, 512)    2048        conv2d_223[0][0]
# __________________________________________________________________________________________________
# activation_245 (Activation)     (None, 3, 3, 512)    0           batch_normalization_223[0][0]
# __________________________________________________________________________________________________
# conv2d_224 (Conv2D)             (None, 3, 3, 2048)   1050624     activation_245[0][0]
# __________________________________________________________________________________________________
# batch_normalization_224 (BatchN (None, 3, 3, 2048)   8192        conv2d_224[0][0]
# __________________________________________________________________________________________________
# activation_246 (Activation)     (None, 3, 3, 2048)   0           batch_normalization_224[0][0]
# __________________________________________________________________________________________________
# add_63 (Add)                    (None, 3, 3, 2048)   0           activation_246[0][0]
#                                                                  activation_243[0][0]
# __________________________________________________________________________________________________
# activation_247 (Activation)     (None, 3, 3, 2048)   0           add_63[0][0]
# __________________________________________________________________________________________________
# conv2d_225 (Conv2D)             (None, 3, 3, 512)    1049088     activation_247[0][0]
# __________________________________________________________________________________________________
# batch_normalization_225 (BatchN (None, 3, 3, 512)    2048        conv2d_225[0][0]
# __________________________________________________________________________________________________
# activation_248 (Activation)     (None, 3, 3, 512)    0           batch_normalization_225[0][0]
# __________________________________________________________________________________________________
# conv2d_226 (Conv2D)             (None, 3, 3, 512)    2359808     activation_248[0][0]
# __________________________________________________________________________________________________
# batch_normalization_226 (BatchN (None, 3, 3, 512)    2048        conv2d_226[0][0]
# __________________________________________________________________________________________________
# activation_249 (Activation)     (None, 3, 3, 512)    0           batch_normalization_226[0][0]
# __________________________________________________________________________________________________
# conv2d_227 (Conv2D)             (None, 3, 3, 2048)   1050624     activation_249[0][0]
# __________________________________________________________________________________________________
# batch_normalization_227 (BatchN (None, 3, 3, 2048)   8192        conv2d_227[0][0]
# __________________________________________________________________________________________________
# activation_250 (Activation)     (None, 3, 3, 2048)   0           batch_normalization_227[0][0]
# __________________________________________________________________________________________________
# add_64 (Add)                    (None, 3, 3, 2048)   0           activation_250[0][0]
#                                                                  activation_247[0][0]
# __________________________________________________________________________________________________
# activation_251 (Activation)     (None, 3, 3, 2048)   0           add_64[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_1 (AveragePoo (None, 2, 2, 2048)   0           activation_251[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 8192)         0           average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 3)            24579       flatten_1[0][0]
# ==================================================================================================
# Total params: 23,612,291
# Trainable params: 23,559,171
# Non-trainable params: 53,120
# __________________________________________________________________________________________________
